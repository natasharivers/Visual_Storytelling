# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import seaborn as sns
from env import host, user, password

# %%
telco_rivers_churn= pd.read_csv('churn_m2m.csv')
telco_rivers_churn
#this will show my data on only month-to-month customers
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     5287-QWLKY    Male                  1     Yes        Yes              2
# 1     5502-RLUYV  Female                  0     Yes        Yes              2
# 2     0979-PHULV    Male                  0     Yes        Yes              2
# 3     9090-SGQXL    Male                  1     Yes         No              2
# 4     4550-VBOFE    Male                  1     Yes         No              2
# ...          ...     ...                ...     ...        ...            ...
# 1651  9894-EZEWG  Female                  0      No         No              1
# 1652  9907-SWKKF  Female                  1      No         No              0
# 1653  9940-RHLFB  Female                  0      No         No              1
# 1654  9974-JFBHQ  Female                  0     Yes        Yes              0
# 1655  9995-HOTOH  Female                  0      No         No              1
#
# ...

# %%
senior_count = telco_rivers_churn['is_senior_citizen'].value_counts()
senior_count
#this counts who is and isn't 'senior citizen' among month-to-month customers
# Out:
# 0    1215
# 1     441
# Name: is_senior_citizen, dtype: int64

# %%
dependents_count = telco_rivers_churn['dependents'].value_counts()
dependents_count
#this counts who has and doesnt have 'dependents' among month-to-month customers
# Out:
# No     1396
# Yes     260
# Name: dependents, dtype: int64

# %%
telco_rivers_churn.count()
#there are 1654 customers/ 2 invalid data (no customer_id)- toss out
# Out:
# customer_id                 1654
# gender                      1656
# is_senior_citizen           1656
# partner                     1656
# dependents                  1656
# phone_service               1656
# phone_service_VLookup       1656
# internet_service            1656
# internet_service_VLookup    1656
# contract_type               1656
# contract_type_VLookup       1656
# payment_type                1655
# monthly_charges             1656
# total_charges               1656
# churn                       1656
# tenure                      1656
# is_female                   1656
# has_churned                 1656
# has_phone                   1656
# has_internet                1656
# has_phone_and_internet      1656
# partner_dependents          1656
# start_date                     0
# monthly_charges.1           1656
# dtype: int64

# %%
telco_rivers_churn.count['tenure']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-61e406857bcd> in <module>
# ----> 1 telco_rivers_churn.count['tenure']
#
# TypeError: 'method' object is not subscriptable
