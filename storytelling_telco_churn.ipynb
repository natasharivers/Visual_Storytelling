# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import seaborn as sns
from env import host, user, password

# %%
telco_rivers_churn= pd.read_csv('churn_exercise.csv')
telco_rivers_churn
# Out:
#               customer_id  gender is_senior_citizen    partner dependents  \
# 0              5287-QWLKY    Male                 1        Yes        Yes
# 1              5502-RLUYV  Female                 0        Yes        Yes
# 2              0979-PHULV    Male                 0        Yes        Yes
# 3              9090-SGQXL    Male                 1        Yes         No
# 4              4550-VBOFE    Male                 1        Yes         No
# ...                   ...     ...               ...        ...        ...
# 1657                  NaN  Gender            senior  Dependant    Partner
# 1658               Is/Has     843               441        541        260
# 1659  Is not/ Doesnt Have     813              1215       1115       1396
# 1660                  NaN     NaN               NaN        NaN        NaN
# 1661                 1654     NaN               NaN        NaN        NaN
#
#       phone_service phone_service_VLookup  internet_service  \
# ...
